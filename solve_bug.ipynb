# %%
import utils.preprocessing_v2 as preproc_new
import utils.preprocessing as preproc_old
from utils.load_data import load_data, load_gt_data

TRAIN_PROPORTION = 0.9
MODE = "pct" # None | "pct" | "diff"
PERIOD = 4  # Year to year prediction

# %%
# NEW
data_new, all_gdps_new, all_gts_new = preproc_new.load_data()
data_old, all_gdps_old, all_gts_old = preproc_new.load_data()
